# %% [markdown]
# #Library

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Preprocessing

# %%
y =  pd.read_csv("/content/drive/MyDrive/pengantar analisis data/pilkada-100-uas.csv")
df = pd.read_csv('/content/drive/MyDrive/pengantar analisis data/pilkada-1000-uas.csv')

# %%
y
# Out:
#    Hasil Pilkada  Jumlah Paslon             Nama Daerah Jalur Pencalonan  \
# 0          Kalah              3  KABUPATEN TOBA SAMOSIR       PERORANGAN
# 1          Kalah              5  KABUPATEN TOJO UNA UNA           PARPOL
# 2         Menang              5  KABUPATEN TOJO UNA UNA           PARPOL
# 3          Kalah              5  KABUPATEN TOJO UNA UNA           PARPOL
# 4          Kalah              5  KABUPATEN TOJO UNA UNA       PERORANGAN
# ..           ...            ...                     ...              ...
# 95         Kalah              3        Sulawesi Selatan           PARPOL
# 96         Kalah              4                 Lampung           PARPOL
# 97        Menang              4                 Lampung           PARPOL
# 98         Kalah              4                 Lampung           PARPOL
# 99         Kalah              4                 Lampung           PARPOL
#
#                 Nama Kandidat (1)                          Nama Kandidat (2)  \
# ...

# %%
df
# Out:
#     Hasil Pilkada  Jumlah Paslon                    Nama Daerah  \
# 0           Kalah              3              Provinsi Bengkulu
# 1          Menang              3              Provinsi Bengkulu
# 2           Kalah              3              Provinsi Bengkulu
# 3           Kalah              3                 Provinsi Jambi
# 4           Kalah              3                 Provinsi Jambi
# ..            ...            ...                            ...
# 995         Kalah              4  KOTA MOJOKERTO (JAWA TIMUR)
# 996        Menang              4  KOTA MOJOKERTO (JAWA TIMUR)
# 997        Menang              3     KOTA MADIUN (JAWA TIMUR)
# 998         Kalah              3     KOTA MADIUN (JAWA TIMUR)
# 999         Kalah              3     KOTA MADIUN (JAWA TIMUR)
#
#     Jalur Pencalonan            Nama Kandidat (1)  \
# 0             PARPOL                  Helmi Hasan
# 1             PARPOL              Rohidin Mersyah
# 2             PARPOL   Agusrin Maryono Najamuddin
# ...

# %%
df.columns
# Out:
# Index(['Hasil Pilkada', 'Jumlah Paslon', 'Nama Daerah', 'Jalur Pencalonan',
#        'Nama Kandidat (1)', 'Nama Kandidat (2)', 'Gender (1)', 'Gender (2)',
#        'Usia (1)', 'Usia (2)', 'Latar Belakang Profesi (1)',
#        'Latar Belakang Profesi (2)', 'Petahana? (1)', 'Petahana? (2)',
#        'Jumlah PARPOL Pendukung', 'Persentase PARPOL Pendukung',
#        'Jumlah Kursi Pendukung (DPR)', 'Jumlah Kursi Pendukung (DPRD)'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Hasil Pilkada                     object
# Jumlah Paslon                      int64
# Nama Daerah                       object
# Jalur Pencalonan                  object
# Nama Kandidat (1)                 object
# Nama Kandidat (2)                 object
# Gender (1)                        object
# Gender (2)                        object
# Usia (1)                           int64
# Usia (2)                           int64
# Latar Belakang Profesi (1)        object
# Latar Belakang Profesi (2)        object
# Petahana? (1)                      int64
# Petahana? (2)                      int64
# Jumlah PARPOL Pendukung            int64
# Persentase PARPOL Pendukung      float64
# Jumlah Kursi Pendukung (DPR)     float64
# Jumlah Kursi Pendukung (DPRD)    float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Hasil Pilkada                    0
# Jumlah Paslon                    0
# Nama Daerah                      0
# Jalur Pencalonan                 0
# Nama Kandidat (1)                0
# Nama Kandidat (2)                0
# Gender (1)                       0
# Gender (2)                       0
# Usia (1)                         0
# Usia (2)                         0
# Latar Belakang Profesi (1)       0
# Latar Belakang Profesi (2)       0
# Petahana? (1)                    0
# Petahana? (2)                    0
# Jumlah PARPOL Pendukung          0
# Persentase PARPOL Pendukung      0
# Jumlah Kursi Pendukung (DPR)     0
# Jumlah Kursi Pendukung (DPRD)    0
# dtype: int64

# %%
df['Hasil Pilkada'].unique()
# Out:
# array(['Kalah', 'Menang'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

df['Nama Daerah'] = le.fit_transform(df['Nama Daerah'])
df['Jalur Pencalonan'] = le.fit_transform(df['Jalur Pencalonan'])
df['Nama Kandidat (1)'] = le.fit_transform(df['Nama Kandidat (1)'])
df['Nama Kandidat (2)'] = le.fit_transform(df['Nama Kandidat (2)'])
df['Gender (1)'] = le.fit_transform(df['Gender (1)'])
df['Gender (2)'] = le.fit_transform(df['Gender (2)'])
df['Latar Belakang Profesi (1)'] = le.fit_transform(df['Latar Belakang Profesi (1)'])
df['Latar Belakang Profesi (2)'] = le.fit_transform(df['Latar Belakang Profesi (2)'])

df[['Nama Daerah', 'Jalur Pencalonan', 'Nama Kandidat (1)', 'Nama Kandidat (2)', 'Gender (1)', 'Gender (2)', 'Latar Belakang Profesi (1)', 'Latar Belakang Profesi (2)']]
# Out:
#      Nama Daerah  Jalur Pencalonan  Nama Kandidat (1)  Nama Kandidat (2)  \
# 0            255                 0                470                679
# 1            255                 0                808                772
# 2            255                 0                 54                502
# 3            256                 0                165                748
# 4            256                 0                322                870
# ..           ...               ...                ...                ...
# 995          106                 0                946                599
# 996          106                 0                444                  3
# 997          104                 0                235                459
# 998          104                 1                203                  7
# 999          104                 0                955                129
#
#      Gender (1)  Gender (2)  Latar Belakang Profesi (1)  \
# ...

# %%
replace_dict = {'Kalah': 0, 'Menang': 1}

# Replace the values in 'col2' using the replace_dict
df['Hasil Pilkada'] = df['Hasil Pilkada'].replace(replace_dict)
df
# Out:
#      Hasil Pilkada  Jumlah Paslon  Nama Daerah  Jalur Pencalonan  \
# 0                0              3          255                 0
# 1                1              3          255                 0
# 2                0              3          255                 0
# 3                0              3          256                 0
# 4                0              3          256                 0
# ..             ...            ...          ...               ...
# 995              0              4          106                 0
# 996              1              4          106                 0
# 997              1              3          104                 0
# 998              0              3          104                 1
# 999              0              3          104                 0
#
#      Nama Kandidat (1)  Nama Kandidat (2)  Gender (1)  Gender (2)  Usia (1)  \
# 0                  470                679           0           0        41
# ...

# %%
df.corr(method='kendall')
# Out:
#                                Hasil Pilkada  Jumlah Paslon  Nama Daerah  \
# Hasil Pilkada                       1.000000      -0.247025     0.021344
# Jumlah Paslon                      -0.247025       1.000000    -0.090101
# Nama Daerah                         0.021344      -0.090101     1.000000
# Jalur Pencalonan                   -0.189362       0.212549    -0.034682
# Nama Kandidat (1)                  -0.020781      -0.013730     0.003826
# Nama Kandidat (2)                   0.022993      -0.032449     0.081795
# Gender (1)                          0.004991      -0.011407    -0.045352
# Gender (2)                         -0.006307      -0.034047    -0.012276
# Usia (1)                           -0.102024       0.032448     0.024024
# Usia (2)                            0.008256      -0.000446    -0.002867
# Latar Belakang Profesi (1)         -0.004535       0.004300     0.026318
# Latar Belakang Profesi (2)         -0.017714      -0.007666    -0.005432
# ...
